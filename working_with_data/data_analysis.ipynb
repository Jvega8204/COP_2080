# %%
import faker 
fake = faker.Faker()

print(fake.email())
print(fake.address())
print(fake.company())
# Out:
# jaredwright@example.net
# 916 Jacob Mountains
# Steveton, MP 34430
# Norris, Thompson and Johnson

# %%
#create a user 
users= []

for i in range(10):
    user = {
        "username": fake.unique.user_name(),
        "name": fake.name(),
        "email": fake.email(),
        "address":fake.address(),
        "age": fake.random_int(min=18, max = 90)

    }
    user.append(user)
with open("users.json", "w
# Out:
# {'username': 'marcus99', 'name': 'Hannah Clayton', 'email': 'schaeferglenn@example.org', 'address': '783 Weaver Grove Suite 495\nDukeborough, PR 44583', 'age': 78}
